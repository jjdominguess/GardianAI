# %% [markdown]
# <a href="https://colab.research.google.com/github/jjdominguess/GardianAI/blob/main/esp32_leituras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = """
IdLeitura,Temperature_C,Humidity_%
0,nan,nan
1,-8.40,77.0
2,-8.40,77.0
3,-8.40,77.0
4,-8.40,77.0
5,42.10,77.0
6,42.10,45.0
7,42.10,45.0
8,42.10,27.5
9,42.10,76.5
10,-17.90,62.0
11,18.10,59.0
12,45.60,59.0
13,55.00,59.0
14,9.60,59.0
15,-40.00,59.0
16,-40.00,100.0
17,41.30,40.0
18,41.30,40.0
19,41.30,40.0
20,41.30,40.0
"""

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# Load the CSV file
# Make sure to save the serial output as 'dados_sensor.csv' first
df = pd.read_csv(StringIO(data))

# Optional: print the first few rows to verify
print(df.head())

# Plot temperature
plt.figure(figsize=(10, 5))
plt.plot(df['IdLeitura'], df['Temperature_C'], label='Temperature (°C)', marker='o')
plt.plot(df['IdLeitura'], df['Humidity_%'], label='Humidity (%)', marker='s')

plt.title('Sensor Readings Over Time')
plt.xlabel('Time (seconds)')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#    IdLeitura  Temperature_C  Humidity_%
# 0          0            NaN         NaN
# 1          1           -8.4        77.0
# 2          2           -8.4        77.0
# 3          3           -8.4        77.0
# 4          4           -8.4        77.0
